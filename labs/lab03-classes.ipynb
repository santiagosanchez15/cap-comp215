# %% [markdown]
# COMP 215 - LAB 3 Classes (NEO)
# ----------------
# #### Name: Santiago Sanchez
# #### Date: jan 19 2026
#
# This lab exercise introduces `class` as a means of organizing related data and functions.
#
# **Building on new concepts from lab 2**:
#   * a `record` is a related collection of data, with fields for each data value
#   * an `API` is an "Application Programmers Interface" defining how a programmer interacts with a system.
#   * *f-string* simplifies string formatting operations
#
# **New Python Concepts**:
#   * the `class` keyword allows you define a new data `type`, with a set of operations on that data.
#   * a `dataclass` simplifies class definition for classes that primarily encapsulate a data structure.
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures
from dataclasses import dataclass, field

# %% [markdown]
# We'll continue working with [Near Earth Object](https://cneos.jpl.nasa.gov/) data
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# Here's a brief review from Lab 2 on how to use it...

# %% [markdown]
# ### Review: making a query
#
# Here's a query that gets the record for a single NEO that recently passed by.

# %%
API_KEY = 'xyNPea9FbORs6vJGjZHmOWWabcitT0WbgaG9Wfgh'  # substitute your API key here

def get_neos(start_date):
    """ Return a list of NEO for the week starting at start_date """
    url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={start_date}&api_key={API_KEY}'
    # Fetch last week's NEO feed
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)
    return [neo for dated_records in data['near_earth_objects'].values() for neo in dated_records ]

def get_neo(id):
    """ Return a NEO record for the given id """
    url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
    response = requests.request("GET", url, headers={}, data={})
    return json.loads(response.text)

# Sample usage:  get the list of NEOs for a given week, then lookup the latest NEO record in that list.
week_start = '2023-01-15'
neos = get_neos(week_start)
print(f'{len(neos)} Near Earth Objects found for week of {week_start}')
assert len(neos) > 0, f'Oh oh!  No NEOs found for {week_start}'
neo = get_neo(neos[-1]['id'])  # get the very latest NEO
pprint(neo)
# Out:
# 31 Near Earth Objects found for week of 2023-01-15
# {'absolute_magnitude_h': 23.53,
#  'close_approach_data': [{'close_approach_date': '1903-10-03',
#                           'close_approach_date_full': '1903-Oct-03 16:52',
#                           'epoch_date_close_approach': -2090560080000,
#                           'miss_distance': {'astronomical': '0.4041582271',
#                                             'kilometers': '60461209.917136277',
#                                             'lunar': '157.2175503419',
#                                             'miles': '37568853.7516115426'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16755.6588868038',
#                                                 'kilometers_per_second': '4.6543496908',
#                                                 'miles_per_hour': '10411.3148233032'}},
#                          {'close_approach_date': '1908-11-10',
#                           'close_approach_date_full': '1908-Nov-10 03:11',
#                           'epoch_date_close_approach': -1929473340000,
#                           'miss_distance': {'astronomical': '0.2598477412',
#                                             'kilometers': '38872668.607831244',
#                                             'lunar': '101.0807713268',
#                                             'miles': '24154356.2205254072'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11965.6356455529',
#                                                 'kilometers_per_second': '3.3237876793',
#                                                 'miles_per_hour': '7434.9806598715'}},
#                          {'close_approach_date': '1912-11-27',
#                           'close_approach_date_full': '1912-Nov-27 13:00',
#                           'epoch_date_close_approach': -1801738800000,
#                           'miss_distance': {'astronomical': '0.0835173796',
#                                             'kilometers': '12494022.096141452',
#                                             'lunar': '32.4882606644',
#                                             'miles': '7763425.3357259576'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '20650.4407741696',
#                                                 'kilometers_per_second': '5.7362335484',
#                                                 'miles_per_hour': '12831.3808243722'}},
#                          {'close_approach_date': '1913-12-20',
#                           'close_approach_date_full': '1913-Dec-20 10:43',
#                           'epoch_date_close_approach': -1768223820000,
#                           'miss_distance': {'astronomical': '0.1524758561',
#                                             'kilometers': '22810063.298986507',
#                                             'lunar': '59.3131080229',
#                                             'miles': '14173516.0993155166'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11040.4893844971',
#                                                 'kilometers_per_second': '3.0668026068',
#                                                 'miles_per_hour': '6860.1307511615'}},
#                          {'close_approach_date': '1919-02-17',
#                           'close_approach_date_full': '1919-Feb-17 12:46',
#                           'epoch_date_close_approach': -1605352440000,
#                           'miss_distance': {'astronomical': '0.2817055758',
#                                             'kilometers': '42142554.106803546',
#                                             'lunar': '109.5834689862',
#                                             'miles': '26186168.8531830948'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '5831.5897982645',
#                                                 'kilometers_per_second': '1.6198860551',
#                                                 'miles_per_hour': '3623.5231165939'}},
#                          {'close_approach_date': '1924-03-28',
#                           'close_approach_date_full': '1924-Mar-28 18:58',
#                           'epoch_date_close_approach': -1444107720000,
#                           'miss_distance': {'astronomical': '0.4035840619',
#                                             'kilometers': '60375316.026188153',
#                                             'lunar': '156.9942000791',
#                                             'miles': '37515481.7626683914'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18075.0594625637',
#                                                 'kilometers_per_second': '5.0208498507',
#                                                 'miles_per_hour': '11231.139031058'}},
#                          {'close_approach_date': '1929-04-22',
#                           'close_approach_date_full': '1929-Apr-22 14:43',
#                           'epoch_date_close_approach': -1284196620000,
#                           'miss_distance': {'astronomical': '0.496136432',
#                                             'kilometers': '74220953.45659984',
#                                             'lunar': '192.997072048',
#                                             'miles': '46118761.922524192'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24520.6248468144',
#                                                 'kilometers_per_second': '6.8112846797',
#                                                 'miles_per_hour': '15236.1626999553'}},
#                          {'close_approach_date': '1936-09-20',
#                           'close_approach_date_full': '1936-Sep-20 00:39',
#                           'epoch_date_close_approach': -1050276060000,
#                           'miss_distance': {'astronomical': '0.4559543153',
#                                             'kilometers': '68209794.386188411',
#                                             'lunar': '177.3662286517',
#                                             'miles': '42383600.8778896318'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19586.5560734547',
#                                                 'kilometers_per_second': '5.4407100204',
#                                                 'miles_per_hour': '12170.3242446419'}},
#                          {'close_approach_date': '1941-10-22',
#                           'close_approach_date_full': '1941-Oct-22 19:52',
#                           'epoch_date_close_approach': -889675680000,
#                           'miss_distance': {'astronomical': '0.3294306336',
#                                             'kilometers': '49282121.099310432',
#                                             'lunar': '128.1485164704',
#                                             'miles': '30622490.0673786816'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '13657.2176593614',
#                                                 'kilometers_per_second': '3.793671572',
#                                                 'miles_per_hour': '8486.0639395071'}},
#                          {'close_approach_date': '1946-12-04',
#                           'close_approach_date_full': '1946-Dec-04 15:47',
#                           'epoch_date_close_approach': -728208780000,
#                           'miss_distance': {'astronomical': '0.1760096844',
#                                             'kilometers': '26330673.885612228',
#                                             'lunar': '68.4677672316',
#                                             'miles': '16361122.0772076264'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11359.8902440294',
#                                                 'kilometers_per_second': '3.1555250678',
#                                                 'miles_per_hour': '7058.5940241304'}},
#                          {'close_approach_date': '1952-01-16',
#                           'close_approach_date_full': '1952-Jan-16 16:13',
#                           'epoch_date_close_approach': -566725620000,
#                           'miss_distance': {'astronomical': '0.2123020095',
#                                             'kilometers': '31759928.417919765',
#                                             'lunar': '82.5854816955',
#                                             'miles': '19734704.408492157'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '7940.5741333697',
#                                                 'kilometers_per_second': '2.205715037',
#                                                 'miles_per_hour': '4933.9639663708'}},
#                          {'close_approach_date': '1957-03-14',
#                           'close_approach_date_full': '1957-Mar-14 03:04',
#                           'epoch_date_close_approach': -403995360000,
#                           'miss_distance': {'astronomical': '0.3510701408',
#                                             'kilometers': '52519345.284280096',
#                                             'lunar': '136.5662847712',
#                                             'miles': '32634007.9005974848'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '13374.7962263927',
#                                                 'kilometers_per_second': '3.715221174',
#                                                 'miles_per_hour': '8310.5782441161'}},
#                          {'close_approach_date': '1962-04-12',
#                           'close_approach_date_full': '1962-Apr-12 12:30',
#                           'epoch_date_close_approach': -243689400000,
#                           'miss_distance': {'astronomical': '0.4552244777',
#                                             'kilometers': '68100612.235782499',
#                                             'lunar': '177.0823218253',
#                                             'miles': '42315758.2355325262'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '21930.7158520664',
#                                                 'kilometers_per_second': '6.0918655145',
#                                                 'miles_per_hour': '13626.8939693021'}},
#                          {'close_approach_date': '1974-10-06',
#                           'close_approach_date_full': '1974-Oct-06 08:11',
#                           'epoch_date_close_approach': 150279060000,
#                           'miss_distance': {'astronomical': '0.3959435811',
#                                             'kilometers': '59232316.372732257',
#                                             'lunar': '154.0220530479',
#                                             'miles': '36805254.7116768666'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16413.6784928279',
#                                                 'kilometers_per_second': '4.5593551369',
#                                                 'miles_per_hour': '10198.8215057241'}},
#                          {'close_approach_date': '1979-11-14',
#                           'close_approach_date_full': '1979-Nov-14 10:32',
#                           'epoch_date_close_approach': 311423520000,
#                           'miss_distance': {'astronomical': '0.2489296744',
#                                             'kilometers': '37239349.070033528',
#                                             'lunar': '96.8336433416',
#                                             'miles': '23139458.5211695664'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11898.9990383409',
#                                                 'kilometers_per_second': '3.3052775107',
#                                                 'miles_per_hour': '7393.5752635735'}},
#                          {'close_approach_date': '1984-12-23',
#                           'close_approach_date_full': '1984-Dec-23 08:41',
#                           'epoch_date_close_approach': 472639260000,
#                           'miss_distance': {'astronomical': '0.1556087596',
#                                             'kilometers': '23278738.989502052',
#                                             'lunar': '60.5318074844',
#                                             'miles': '14464737.6692782376'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '10921.091339347',
#                                                 'kilometers_per_second': '3.0336364832',
#                                                 'miles_per_hour': '6785.9414491626'}},
#                          {'close_approach_date': '1990-02-22',
#                           'close_approach_date_full': '1990-Feb-22 04:28',
#                           'epoch_date_close_approach': 635660880000,
#                           'miss_distance': {'astronomical': '0.2911707297',
#                                             'kilometers': '43558520.969465739',
#                                             'lunar': '113.2654138533',
#                                             'miles': '27066009.8628716382'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '7032.2377975498',
#                                                 'kilometers_per_second': '1.9533993882',
#                                                 'miles_per_hour': '4369.5590914831'}},
#                          {'close_approach_date': '1993-10-09',
#                           'close_approach_date_full': '1993-Oct-09 07:46',
#                           'epoch_date_close_approach': 750152760000,
#                           'miss_distance': {'astronomical': '0.0577758711',
#                                             'kilometers': '8643147.253954557',
#                                             'lunar': '22.4748138579',
#                                             'miles': '5370602.6654526066'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '26908.5442378364',
#                                                 'kilometers_per_second': '7.4745956216',
#                                                 'miles_per_hour': '16719.9229460045'}},
#                          {'close_approach_date': '1995-04-01',
#                           'close_approach_date_full': '1995-Apr-01 02:54',
#                           'epoch_date_close_approach': 796704840000,
#                           'miss_distance': {'astronomical': '0.409977859',
#                                             'kilometers': '61331814.45356033',
#                                             'lunar': '159.481387151',
#                                             'miles': '38109822.325499354'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18672.9165133507',
#                                                 'kilometers_per_second': '5.1869212537',
#                                                 'miles_per_hour': '11602.6241524206'}},
#                          {'close_approach_date': '2007-09-22',
#                           'close_approach_date_full': '2007-Sep-22 17:20',
#                           'epoch_date_close_approach': 1190481600000,
#                           'miss_distance': {'astronomical': '0.4516114325',
#                                             'kilometers': '67560108.369648775',
#                                             'lunar': '175.6768472425',
#                                             'miles': '41979904.706852095'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19316.1341928573',
#                                                 'kilometers_per_second': '5.3655928313',
#                                                 'miles_per_hour': '12002.2946044451'}},
#                          {'close_approach_date': '2012-10-24',
#                           'close_approach_date_full': '2012-Oct-24 12:02',
#                           'epoch_date_close_approach': 1351080120000,
#                           'miss_distance': {'astronomical': '0.3249805993',
#                                             'kilometers': '48616405.446603491',
#                                             'lunar': '126.4174531277',
#                                             'miles': '30208833.5422945358'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '13522.1820962873',
#                                                 'kilometers_per_second': '3.7561616934',
#                                                 'miles_per_hour': '8402.1580919959'}},
#                          {'close_approach_date': '2017-12-05',
#                           'close_approach_date_full': '2017-Dec-05 21:14',
#                           'epoch_date_close_approach': 1512508440000,
#                           'miss_distance': {'astronomical': '0.1740934036',
#                                             'kilometers': '26044002.359610332',
#                                             'lunar': '67.7223340004',
#                                             'miles': '16182992.6509213016'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11318.2872952808',
#                                                 'kilometers_per_second': '3.1439686931',
#                                                 'miles_per_hour': '7032.7435696705'}},
#                          {'close_approach_date': '2023-01-18',
#                           'close_approach_date_full': '2023-Jan-18 02:53',
#                           'epoch_date_close_approach': 1674010380000,
#                           'miss_distance': {'astronomical': '0.2140564514',
#                                             'kilometers': '32022389.189198518',
#                                             'lunar': '83.2679595946',
#                                             'miles': '19897789.9693868284'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '7588.1173194172',
#                                                 'kilometers_per_second': '2.1078103665',
#                                                 'miles_per_hour': '4714.9610088346'}},
#                          {'close_approach_date': '2028-03-14',
#                           'close_approach_date_full': '2028-Mar-14 18:18',
#                           'epoch_date_close_approach': 1836670680000,
#                           'miss_distance': {'astronomical': '0.3507480963',
#                                             'kilometers': '52471168.113034881',
#                                             'lunar': '136.4410094607',
#                                             'miles': '32604071.9945321178'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '13440.4974942722',
#                                                 'kilometers_per_second': '3.7334715262',
#                                                 'miles_per_hour': '8351.4024569271'}},
#                          {'close_approach_date': '2033-04-12',
#                           'close_approach_date_full': '2033-Apr-12 20:21',
#                           'epoch_date_close_approach': 1996950060000,
#                           'miss_distance': {'astronomical': '0.4541835878',
#                                             'kilometers': '67944897.323837986',
#                                             'lunar': '176.6774156542',
#                                             'miles': '42219001.4759207668'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '21859.2579700877',
#                                                 'kilometers_per_second': '6.0720161028',
#                                                 'miles_per_hour': '13582.4928203581'}},
#                          {'close_approach_date': '2045-10-05',
#                           'close_approach_date_full': '2045-Oct-05 18:18',
#                           'epoch_date_close_approach': 2390840280000,
#                           'miss_distance': {'astronomical': '0.4002025661',
#                                             'kilometers': '59869451.457094207',
#                                             'lunar': '155.6787982129',
#                                             'miles': '37201152.0950937766'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16723.4813072355',
#                                                 'kilometers_per_second': '4.6454114742',
#                                                 'miles_per_hour': '10391.3209267097'}},
#                          {'close_approach_date': '2050-11-12',
#                           'close_approach_date_full': '2050-Nov-12 20:09',
#                           'epoch_date_close_approach': 2551896540000,
#                           'miss_distance': {'astronomical': '0.2560182082',
#                                             'kilometers': '38299778.627936534',
#                                             'lunar': '99.5910829898',
#                                             'miles': '23798378.8939068092'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '12026.3790380081',
#                                                 'kilometers_per_second': '3.3406608439',
#                                                 'miles_per_hour': '7472.7242417001'}},
#                          {'close_approach_date': '2055-12-22',
#                           'close_approach_date_full': '2055-Dec-22 16:20',
#                           'epoch_date_close_approach': 2713105200000,
#                           'miss_distance': {'astronomical': '0.1537774545',
#                                             'kilometers': '23004779.647221915',
#                                             'lunar': '59.8194298005',
#                                             'miles': '14294507.227675827'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '10936.8504382281',
#                                                 'kilometers_per_second': '3.0380140106',
#                                                 'miles_per_hour': '6795.7335403535'}},
#                          {'close_approach_date': '2061-02-18',
#                           'close_approach_date_full': '2061-Feb-18 23:19',
#                           'epoch_date_close_approach': 2875994340000,
#                           'miss_distance': {'astronomical': '0.281571419',
#                                             'kilometers': '42122484.53527753',
#                                             'lunar': '109.531281991',
#                                             'miles': '26173698.199708714'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '6006.7932697144',
#                                                 'kilometers_per_second': '1.668553686',
#                                                 'miles_per_hour': '3732.3877402845'}},
#                          {'close_approach_date': '2061-06-26',
#                           'close_approach_date_full': '2061-Jun-26 05:29',
#                           'epoch_date_close_approach': 2886989340000,
#                           'miss_distance': {'astronomical': '0.0260822927',
#                                             'kilometers': '3901855.432636549',
#                                             'lunar': '10.1460118603',
#                                             'miles': '2424500.5402564162'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '24749.9983626612',
#                                                 'kilometers_per_second': '6.8749995452',
#                                                 'miles_per_hour': '15378.6864826213'}},
#                          {'close_approach_date': '2066-03-30',
#                           'close_approach_date_full': '2066-Mar-30 00:40',
#                           'epoch_date_close_approach': 3037135200000,
#                           'miss_distance': {'astronomical': '0.4002026278',
#                                             'kilometers': '59869460.687282786',
#                                             'lunar': '155.6788222142',
#                                             'miles': '37201157.8304670068'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '17932.663350883',
#                                                 'kilometers_per_second': '4.9812953752',
#                                                 'miles_per_hour': '11142.6596248862'}},
#                          {'close_approach_date': '2071-04-23',
#                           'close_approach_date_full': '2071-Apr-23 15:14',
#                           'epoch_date_close_approach': 3197027640000,
#                           'miss_distance': {'astronomical': '0.4916845583',
#                                             'kilometers': '73554962.633570821',
#                                             'lunar': '191.2652931787',
#                                             'miles': '45704934.4145304898'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24354.2118184647',
#                                                 'kilometers_per_second': '6.7650588385',
#                                                 'miles_per_hour': '15132.7601157566'}},
#                          {'close_approach_date': '2078-09-19',
#                           'close_approach_date_full': '2078-Sep-19 21:20',
#                           'epoch_date_close_approach': 3430848000000,
#                           'miss_distance': {'astronomical': '0.4649758223',
#                                             'kilometers': '69559392.617578501',
#                                             'lunar': '180.8755948747',
#                                             'miles': '43222202.3324092738'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '20057.0016045569',
#                                                 'kilometers_per_second': '5.5713893346',
#                                                 'miles_per_hour': '12462.6408025648'}},
#                          {'close_approach_date': '2083-10-20',
#                           'close_approach_date_full': '2083-Oct-20 14:22',
#                           'epoch_date_close_approach': 3591267720000,
#                           'miss_distance': {'astronomical': '0.3455971255',
#                                             'kilometers': '51700593.852922685',
#                                             'lunar': '134.4372818195',
#                                             'miles': '32125259.352135653'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '14315.4501531286',
#                                                 'kilometers_per_second': '3.9765139314',
#                                                 'miles_per_hour': '8895.0640132037'}},
#                          {'close_approach_date': '2088-11-29',
#                           'close_approach_date_full': '2088-Nov-29 23:28',
#                           'epoch_date_close_approach': 3752609280000,
#                           'miss_distance': {'astronomical': '0.1944273643',
#                                             'kilometers': '29085919.568994041',
#                                             'lunar': '75.6322447127',
#                                             'miles': '18073152.3569621258'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11469.6461760417',
#                                                 'kilometers_per_second': '3.1860128267',
#                                                 'miles_per_hour': '7126.7920919966'}},
#                          {'close_approach_date': '2094-01-08',
#                           'close_approach_date_full': '2094-Jan-08 00:41',
#                           'epoch_date_close_approach': 3913749660000,
#                           'miss_distance': {'astronomical': '0.1892882894',
#                                             'kilometers': '28317124.910183578',
#                                             'lunar': '73.6331445766',
#                                             'miles': '17595445.5075382564'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '9579.0704359193',
#                                                 'kilometers_per_second': '2.6608528989',
#                                                 'miles_per_hour': '5952.0618494744'}},
#                          {'close_approach_date': '2099-03-09',
#                           'close_approach_date_full': '2099-Mar-09 08:07',
#                           'epoch_date_close_approach': 4076726820000,
#                           'miss_distance': {'astronomical': '0.3287517887',
#                                             'kilometers': '49180567.348210069',
#                                             'lunar': '127.8844458043',
#                                             'miles': '30559387.4925501922'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11263.2070275191',
#                                                 'kilometers_per_second': '3.1286686188',
#                                                 'miles_per_hour': '6998.5188332938'}},
#                          {'close_approach_date': '2104-04-09',
#                           'close_approach_date_full': '2104-Apr-09 16:44',
#                           'epoch_date_close_approach': 4237202640000,
#                           'miss_distance': {'astronomical': '0.4361477146',
#                                             'kilometers': '65246769.109527902',
#                                             'lunar': '169.6614609794',
#                                             'miles': '40542462.3457009676'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '20632.926122699',
#                                                 'kilometers_per_second': '5.7313683674',
#                                                 'miles_per_hour': '12820.4979010737'}},
#                          {'close_approach_date': '2116-09-30',
#                           'close_approach_date_full': '2116-Sep-30 19:10',
#                           'epoch_date_close_approach': 4630936200000,
#                           'miss_distance': {'astronomical': '0.4258002411',
#                                             'kilometers': '63698809.114046457',
#                                             'lunar': '165.6362937879',
#                                             'miles': '39580604.6064448266'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18048.6211185881',
#                                                 'kilometers_per_second': '5.0135058663',
#                                                 'miles_per_hour': '11214.7112722694'}},
#                          {'close_approach_date': '2121-11-04',
#                           'close_approach_date_full': '2121-Nov-04 19:00',
#                           'epoch_date_close_approach': 4791726000000,
#                           'miss_distance': {'astronomical': '0.2913670704',
#                                             'kilometers': '43587893.119980048',
#                                             'lunar': '113.3417903856',
#                                             'miles': '27084260.8708907424'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '12710.7988576728',
#                                                 'kilometers_per_second': '3.5307774605',
#                                                 'miles_per_hour': '7897.9961013134'}},
#                          {'close_approach_date': '2126-12-15',
#                           'close_approach_date_full': '2126-Dec-15 17:27',
#                           'epoch_date_close_approach': 4953029220000,
#                           'miss_distance': {'astronomical': '0.1569011107',
#                                             'kilometers': '23472071.961354209',
#                                             'lunar': '61.0345320623',
#                                             'miles': '14584869.2074137242'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11103.1160669829',
#                                                 'kilometers_per_second': '3.0841989075',
#                                                 'miles_per_hour': '6899.0445361761'}},
#                          {'close_approach_date': '2129-03-13',
#                           'close_approach_date_full': '2129-Mar-13 22:42',
#                           'epoch_date_close_approach': 5023809720000,
#                           'miss_distance': {'astronomical': '0.0224786617',
#                                             'kilometers': '3362759.910770579',
#                                             'lunar': '8.7441994013',
#                                             'miles': '2089522.1161248302'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '24255.7155407793',
#                                                 'kilometers_per_second': '6.7376987613',
#                                                 'miles_per_hour': '15071.5583592137'}},
#                          {'close_approach_date': '2132-02-04',
#                           'close_approach_date_full': '2132-Feb-04 21:09',
#                           'epoch_date_close_approach': 5115215340000,
#                           'miss_distance': {'astronomical': '0.2455327547',
#                                             'kilometers': '36731177.118352489',
#                                             'lunar': '95.5122415783',
#                                             'miles': '22823695.1125387882'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '4149.0825620371',
#                                                 'kilometers_per_second': '1.1525229339',
#                                                 'miles_per_hour': '2578.0785508391'}},
#                          {'close_approach_date': '2137-03-23',
#                           'close_approach_date_full': '2137-Mar-23 19:14',
#                           'epoch_date_close_approach': 5277122040000,
#                           'miss_distance': {'astronomical': '0.37243169',
#                                             'kilometers': '55714987.5445003',
#                                             'lunar': '144.87592741',
#                                             'miles': '34619687.92389214'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '15651.1658551071',
#                                                 'kilometers_per_second': '4.3475460709',
#                                                 'miles_per_hour': '9725.0258059136'}},
#                          {'close_approach_date': '2142-04-19',
#                           'close_approach_date_full': '2142-Apr-19 11:17',
#                           'epoch_date_close_approach': 5437192620000,
#                           'miss_distance': {'astronomical': '0.4697851025',
#                                             'kilometers': '70278850.691731675',
#                                             'lunar': '182.7464048725',
#                                             'miles': '43669252.849680115'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23009.2374835164',
#                                                 'kilometers_per_second': '6.3914548565',
#                                                 'miles_per_hour': '14297.0453685772'}},
#                          {'close_approach_date': '2149-09-14',
#                           'close_approach_date_full': '2149-Sep-14 21:17',
#                           'epoch_date_close_approach': 5670940620000,
#                           'miss_distance': {'astronomical': '0.4901539002',
#                                             'kilometers': '73325979.442112574',
#                                             'lunar': '190.6698671778',
#                                             'miles': '45562650.8571345612'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '21475.9861900329',
#                                                 'kilometers_per_second': '5.9655517195',
#                                                 'miles_per_hour': '13344.3426412457'}},
#                          {'close_approach_date': '2154-10-12',
#                           'close_approach_date_full': '2154-Oct-12 23:33',
#                           'epoch_date_close_approach': 5831134380000,
#                           'miss_distance': {'astronomical': '0.3808173666',
#                                             'kilometers': '56969466.902369142',
#                                             'lunar': '148.1379556074',
#                                             'miles': '35399185.2511004796'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '15890.0770783664',
#                                                 'kilometers_per_second': '4.4139102995',
#                                                 'miles_per_hour': '9873.475949055'}},
#                          {'close_approach_date': '2159-11-21',
#                           'close_approach_date_full': '2159-Nov-21 02:30',
#                           'epoch_date_close_approach': 5992281000000,
#                           'miss_distance': {'astronomical': '0.2339946138',
#                                             'kilometers': '35005095.815952606',
#                                             'lunar': '91.0239047682',
#                                             'miles': '21751157.9254377228'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11811.5328736164',
#                                                 'kilometers_per_second': '3.2809813538',
#                                                 'miles_per_hour': '7339.2271902757'}},
#                          {'close_approach_date': '2164-12-28',
#                           'close_approach_date_full': '2164-Dec-28 11:45',
#                           'epoch_date_close_approach': 6153363900000,
#                           'miss_distance': {'astronomical': '0.1613212035',
#                                             'kilometers': '24133308.429436545',
#                                             'lunar': '62.7539481615',
#                                             'miles': '14995742.496232521'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '10701.362616311',
#                                                 'kilometers_per_second': '2.9726007268',
#                                                 'miles_per_hour': '6649.4105656739'}},
#                          {'close_approach_date': '2170-02-26',
#                           'close_approach_date_full': '2170-Feb-26 22:24',
#                           'epoch_date_close_approach': 6316352640000,
#                           'miss_distance': {'astronomical': '0.2952438374',
#                                             'kilometers': '44167849.205666338',
#                                             'lunar': '114.8498527486',
#                                             'miles': '27444628.8720499444'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '7563.2098985011',
#                                                 'kilometers_per_second': '2.1008916385',
#                                                 'miles_per_hour': '4699.4845060992'}},
#                          {'close_approach_date': '2175-04-04',
#                           'close_approach_date_full': '2175-Apr-04 07:43',
#                           'epoch_date_close_approach': 6477262980000,
#                           'miss_distance': {'astronomical': '0.4100886533',
#                                             'kilometers': '61348389.044848471',
#                                             'lunar': '159.5244861337',
#                                             'miles': '38120121.2989560598'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18738.9192077623',
#                                                 'kilometers_per_second': '5.2052553355',
#                                                 'miles_per_hour': '11643.6356599566'}},
#                          {'close_approach_date': '2180-04-27',
#                           'close_approach_date_full': '2180-Apr-27 03:46',
#                           'epoch_date_close_approach': 6637088760000,
#                           'miss_distance': {'astronomical': '0.4995145914',
#                                             'kilometers': '74726318.907360318',
#                                             'lunar': '194.3111760546',
#                                             'miles': '46432781.4523476684'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24893.4266087262',
#                                                 'kilometers_per_second': '6.9148407246',
#                                                 'miles_per_hour': '15467.807216961'}},
#                          {'close_approach_date': '2187-09-25',
#                           'close_approach_date_full': '2187-Sep-25 05:41',
#                           'epoch_date_close_approach': 6870980460000,
#                           'miss_distance': {'astronomical': '0.4537126157',
#                                             'kilometers': '67874440.900848559',
#                                             'lunar': '176.4942075073',
#                                             'miles': '42175221.8847617542'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19537.99214256',
#                                                 'kilometers_per_second': '5.4272200396',
#                                                 'miles_per_hour': '12140.1485065813'}},
#                          {'close_approach_date': '2192-10-26',
#                           'close_approach_date_full': '2192-Oct-26 05:09',
#                           'epoch_date_close_approach': 7031509740000,
#                           'miss_distance': {'astronomical': '0.3294042324',
#                                             'kilometers': '49278171.536024988',
#                                             'lunar': '128.1382464036',
#                                             'miles': '30620035.9225533144'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '13834.2955877829',
#                                                 'kilometers_per_second': '3.8428598855',
#                                                 'miles_per_hour': '8596.0932778643'}},
#                          {'close_approach_date': '2196-11-28',
#                           'close_approach_date_full': '2196-Nov-28 16:02',
#                           'epoch_date_close_approach': 7160630520000,
#                           'miss_distance': {'astronomical': '0.0232306166',
#                                             'kilometers': '3475250.762146642',
#                                             'lunar': '9.0367098574',
#                                             'miles': '2159420.6899299796'},
#                           'orbiting_body': 'Mars',
#                           'relative_velocity': {'kilometers_per_hour': '23776.6199034277',
#                                                 'kilometers_per_second': '6.6046166398',
#                                                 'miles_per_hour': '14773.8669616604'}},
#                          {'close_approach_date': '2197-12-06',
#                           'close_approach_date_full': '2197-Dec-06 20:30',
#                           'epoch_date_close_approach': 7192873800000,
#                           'miss_distance': {'astronomical': '0.178866735',
#                                             'kilometers': '26758082.56985445',
#                                             'lunar': '69.579159915',
#                                             'miles': '16626701.51851341'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '11349.9383107828',
#                                                 'kilometers_per_second': '3.1527606419',
#                                                 'miles_per_hour': '7052.4102798305'}}],
#  'designation': '2018 AV',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 383.7293606038,
#                                  'estimated_diameter_min': 171.6089870545},
#                         'kilometers': {'estimated_diameter_max': 0.1169607054,
#                                        'estimated_diameter_min': 0.0523064176},
#                         'meters': {'estimated_diameter_max': 116.9607053693,
#                                    'estimated_diameter_min': 52.3064175804},
#                         'miles': {'estimated_diameter_max': 0.0726759905,
#                                   'estimated_diameter_min': 0.032501691}},
#  'id': '3797409',
#  'is_potentially_hazardous_asteroid': False,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3797409?api_key=xyNPea9FbORs6vJGjZHmOWWabcitT0WbgaG9Wfgh'},
#  'name': '(2018 AV)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3797409',
#  'neo_reference_id': '3797409',
#  'orbital_data': {'aphelion_distance': '1.668880515430904',
#                   'ascending_node_longitude': '241.9599511222998',
#                   'data_arc_in_days': 1864,
#                   'eccentricity': '.1945405252179211',
#                   'epoch_osculation': '2461000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '2017-11-17',
#                   'inclination': '6.065358081141168',
#                   'jupiter_tisserand_invariant': '4.735',
#                   'last_observation_date': '2022-12-25',
#                   'mean_anomaly': '275.8974669842871',
#                   'mean_motion': '.5968532176415248',
#                   'minimum_orbit_intersection': '.152446',
#                   'observations_used': 37,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'similar to that '
#                                                              'of 1221 Amor',
#                                   'orbit_class_range': '1.017 AU < q '
#                                                        '(perihelion) < 1.3 AU',
#                                   'orbit_class_type': 'AMO'},
#                   'orbit_determination_date': '2022-12-26 07:02:28',
#                   'orbit_id': '8',
#                   'orbit_uncertainty': '1',
#                   'orbital_period': '603.1633731029311',
#                   'perihelion_argument': '216.652226202787',
#                   'perihelion_distance': '1.12529930551146',
#                   'perihelion_time': '2461141.409909722939',
#                   'semi_major_axis': '1.397089910471182'}}

# %% [markdown]
# ## Exercise 1: Define a CloseApproach class
#
# Each NEO record comes with a list of `close_approach_data`, where each record in this list represents a single “close approach” to another orbiting body.
# * Develop a class named `CloseApproach` to represent a *single* close approach record.
# * State variables are
#     * orbiting body (`str`)
#     * approach date (`datetime` object!)
#     * miss distance (`float` in km, document it!)
#     * relative velocity (`float` in km/hr, ditto)
#
# * Operations must include:
#     * `__init__(self, ...)` method to initialize a new object with specific data values
#     * `__str__(self)` method to return a nicely formatted string representation of the object.
#
# Write a little code to test your new class.

# %%
# Ex. 1 your code here
@dataclass
class CloseApproach:
  '''Class to represent a SINGLE close approach record '''

  orbiting_body: str
  apporach_date: datetime #Get object datetime
  miss_distance: float
  velocity:float

  def __str__(self):
    '''Returns string representation of the object '''

    return f'''{self.orbiting_body} was closed on {self.apporach_date}. The miss distance was {self.miss_distance} km and the relative velocity was {self.velocity} km/hr'''

# %%
# Testing unit
date = datetime.datetime.now()
neo1 = CloseApproach(orbiting_body="Asteroid", apporach_date=date, miss_distance=888999.12322, velocity= 12300)
str(neo1)
# Out:
# 'Asteroid was closed on 2026-01-20 17:36:11.779844. The miss distance was 888999.12322 km and the relative velocity was 12300 km/hr'

# %% [markdown]
# ## Exercise 2: Factory function: get_close_approach
#
# We want to be able to construct CloseApproach objects easily from a data record returned from the NEO API.
#
# Write an "object factory" function...
#
#     def get_close_approach(record):
#         ...
#
# This function provides an easy way to create a `CloseApproach` instance.  It takes a dictionary for a single `close_approach_data` record, constructs and returns a `CloseApproach` object representing that same record.
# This kind of function is called a “Factory” because it handles the details of constructing an object from raw materials.
#
# Remember to convert each element from the data dictionary to the correct type (e.g., parse the date/time string into a `datetime` object).
# Add little code to test your new factory function.

# %% [markdown]
# pseudocode:
# takes dicitonary, from the dicitonary, each key may be something we need to create the objecet
# Therefore, filter, take, and then repeat with each data needed, then return object
# Data needed:
#
# - orbiting body
#
# - approach date, turned to date object
#
# - miss distance
#
# - relative_velocity in kilometers

# %%
# Ex. 2 your code here

def get_close_approach(my_dictionary: dict) -> CloseApproach:
  '''Takes a dicitonary from data and Returns a CloaseApproach Object '''

  #Take individual data
  orbiting = my_dictionary["orbiting_body"] #Get dictionary from list of neos
  approach_date = datetime.date.fromisoformat(my_dictionary["close_approach_date"])
  miss_distance = float(my_dictionary['miss_distance']['kilometers'])
  relative_velocity = float(my_dictionary['relative_velocity']['kilometers_per_hour'])

  return CloseApproach(orbiting_body=orbiting, apporach_date=approach_date, miss_distance=miss_distance, velocity=relative_velocity)

# %%
#unit testing
new_object = get_close_approach(neo["close_approach_data"][0])
print(new_object)
assert type(new_object.apporach_date) == datetime.date
assert type(new_object.miss_distance) == float
# Out:
# Earth was closed on 1903-10-03. The miss distance was 60461209.917136274 km and the relative velocity was 16755.6588868038 km/hr

# %% [markdown]
# ## Exercise 3:  Define an Asteroid class
#
# Define a simple Asteroid class with some basic state variables representing a single NEO.  Your Asteroid class should define at least 4 "state variables:”
# * id  (`int`)
# * name (`str`)
# * estimated_diameter (`float` in m)
# * is_potentially_hazardous (`bool`)
# * close_approaches (`list` of CloseApproach objects, default to empty list)
#
# Operations must include:
# * `__init__(self, ...)` method to initialize a new object with specific data values
# * `__str__(self)` method to return a nicely formatted string representation of the object.
#
# Write a little code to test you new class (just leave close_approaches as an empty list for now).

# %% [markdown]
# Pseudocode
# asteroid class will take
#   - id type int
#   - name str
#   - estimated_diameter type float in meters
#   - is_potenially_hazardous bool
#   - close_apporches llist of closeApproach objects by defaul is []
#
#   methods init and str are expectred

# %%
# Ex. 3 your code here
@dataclass
class Asteroid:

  id: int
  name: str
  estimated_diameter: float #in meters
  is_potentially_hazardous: bool #either True or False
  close_approaches: list = field(default_factory=list)

  def __str__(self) -> str:
    '''Returns description of class Asteroid '''

    return f"{self.name} with id: {self.id}, with an estimated diameter of {self.estimated_diameter}, therefore its level of hazardous is {self.is_potentially_hazardous}"

  def nearest_miss(self):
    '''Returns the CloseApproach object from the asteroid repres '''
    distances = [approach.miss_distance for approach in self.close_approaches] #List comprehension of distances
    new_min = min(distances) #get highest distance

    for approach in self.close_approaches: #See how to improve
       if approach.miss_distance == new_min: return approach

# %%
#Unit testing
new_asteroid = Asteroid(id=1223, name="Big Asteroid", estimated_diameter=1212.78, is_potentially_hazardous=False)

str(new_asteroid)
# Out:
# 'Big Asteroid with id: 1223, with an estimated diameter of 1212.78, therefore its level of hazardous is False'

# %% [markdown]
# ## Exercise 4: Asteroid factory
#
# Write a function that returns an Asteroid object just from the id for a single NEO.
#
#     def asteroid_from_neo(neo_id):
#         ...
#
# This factory function takes the `id` for a single NEO, fetches the NEO record from API, constructs and returns an Asteroid object representing that NEO.  *Hint*: I provided the code fetch a NEO from its `id` above.
#
# Every `Asteroid` should have a list of “close approaches”.
# *Hint*: use the `get_close_approach` factory you defined above to construct the required list of CloseApproach objects.
#
# Now add a new method to `Asteroid` class to return the `CloseApproach` object from the asteroid representing its nearest to **Earth**:
#
#     def nearest_miss(self):
#         ...
#
# Extend your test code to demonstrate these new features.

# %% [markdown]
# code a funciton that takes an id for a NEO recorder from the API
# pass that ID to the get_neo function already written
#
# you should create an Asteroid object for thE given id, use the Asteroid class
#   you will need:
#
#   ID, name, Estimated diameter, hazardous and close approaces:
#
#
#   the first 4 are an specific key inside the neo dictionary,
#
#
#   for the last one, use a list comprehension to get all the close approaches someting, it will return a list of CloseApproach object, and those objects will be in the list
#
#
#   use tghe get_close_approach, since you will be given th edictionary on index [0] of first potion of noe list

# %%
# Ex. 4 your test code for nearest_miss here
def asteroid_from_neo(neo_id) -> Asteroid:
  '''Returns Asteroid object from neo id '''

  new_neo = get_neo(neo_id)
  neo_close_approach = [get_close_approach(approach) for approach in new_neo['close_approach_data'] ]
  return Asteroid(
      id=new_neo['id'],
      name=new_neo['name'],
      estimated_diameter=new_neo['estimated_diameter']['meters'],
      is_potentially_hazardous=new_neo['is_potentially_hazardous_asteroid'],
      close_approaches=neo_close_approach
      )

# %%
#Unit testing

new_asteroid = asteroid_from_neo(neos[-1]['id'])
print(new_asteroid.nearest_miss())
print(new_asteroid.name)
assert type(new_asteroid) == Asteroid
assert type((new_asteroid.nearest_miss())) == CloseApproach
assert new_asteroid.name == '(2018 AV)' #Might change depending on the day because of NASA
# Out:
# Mars was closed on 2129-03-13. The miss distance was 3362759.910770579 km and the relative velocity was 24255.7155407793 km/hr
# (2018 AV)

# %% [markdown]
# ## Challenge - Take your skills to the next level...
# ### Exercise 5: develop a useful analysis / data product
#
#  With these data structures in place, we can now start answering all kinds of interesting questions about a single Asteroid or a set of Asteroids.
# Here’s a couple ideas to try:
#
# * write a **function** named `most_dangerous_approach`, that takes a date range and returns a single “potentially hazardous” Asteroid object that makes the closest approach to Earth within that range.  Your algorithm will ultimately need to:
#     * grab the list of NEO’s for the given date range;
#     * use a list comprehension to build the list of Asteroid objects for the NEO’s returned
#     * use a list comprehension to filter  potentially hazardous Asteroids only;
#     * use a list comprehension to map each Asteroid to its  nearest_miss
#     * apply Python’s min function to identify the Asteroid with the nearest_miss
#
# You may want to decompose some of these steps into smaller functions.
# * add a method to the Asteroid class, `estimated_mass`, that computes an estimate of the Asteroid’s mass based on its diameter.  This is a model – state your assumptions.
# * add a method to the `CloseApproach` class, `impact_force`,  that estimates the force of impact if the Asteroid hit the orbiting object.  Again, this is a model, state your assumptions.

# %%
# Ex. 5 (challenge) your code here
